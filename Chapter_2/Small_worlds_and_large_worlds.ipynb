# %%
import numpy as np
# Out:
# Running cells with 'srbayesianpython (3.12.10) (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/trevorwilliams/github/SRBayesianPython/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
